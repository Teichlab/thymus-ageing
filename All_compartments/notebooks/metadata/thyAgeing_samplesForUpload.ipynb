# %%
import pandas as pd 
import anndata as ad
import hdf5plugin

# %%
adata = ad.read_h5ad('/nfs/team205/lm25/thymus_projects/thymus_ageing_atlas/General_analysis/data/objects/rna/thyAgeing_all_scvi_v5_2025-04-03.zarr', backed='r')

adata

# %%
# Read metadata files and subset to relevant studies
htsa_meta = pd.read_excel('/nfs/team205/lm25/thymus_projects/thymus_ageing_atlas/General_analysis/data/references/htsa/htsa_singleCell_upload.xlsx')
htsa_meta = htsa_meta.loc[htsa_meta['study_group'] == 'HTSA'].copy()

thyAgeing_meta = pd.read_excel('/nfs/team205/lm25/thymus_projects/thymus_ageing_atlas/General_analysis/data/metadata/Thymus_ageing_metadata_v28_2025-03-13.xlsx')
thyAgeing_meta = thyAgeing_meta.loc[thyAgeing_meta['study'].isin(['Thymus_ageing','Yayon2024','Notarangelo2024'])].copy()

# %%
htsa_meta.head()

# %%
thyAgeing_meta['study'].unique()

# %%
upload_meta = thyAgeing_meta.loc[(~thyAgeing_meta['sample'].isin(htsa_meta['sample'])) & (thyAgeing_meta['sample'].isin(adata.obs['sample']))].copy()
upload_meta

# %%
upload_meta['sample'].unique()

# %%
upload_meta.to_csv('/nfs/team205/lm25/thymus_projects/thymus_ageing_atlas/General_analysis/data/metadata/thyAgeing_samplesForUpload.csv', index=False)
